# %% [markdown]
# # 02 — Archive query example
#
# Requires the `[archives]` extra. v1 ships stubbed archive loaders; this notebook documents the expected workflow once they are wired in.

# %%
try:
    import astroquery  # noqa
    HAVE_ARCHIVES = True
except ImportError:
    HAVE_ARCHIVES = False
print('archives extra installed:', HAVE_ARCHIVES)
# Out:
# archives extra installed: False

# %%
if HAVE_ARCHIVES:
    from anomalymetric.ingest.archives import VizierLoader
    try:
        VizierLoader().load('J/A+A/641/A6')  # placeholder catalog id
    except NotImplementedError as exc:
        print('Stubbed:', exc)
else:
    print('Skipping; install with `pip install anomalymetric[archives]`')
# Out:
# Skipping; install with `pip install anomalymetric[archives]`
